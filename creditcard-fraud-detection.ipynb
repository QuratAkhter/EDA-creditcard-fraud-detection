# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('creditcard.csv')

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
frauduent_percentage = ((data['Class'].value_counts()[1]) / len(data)) * 100

# %%
frauduent_percentage
# Out:
# 0.1727485630620034

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data['Amount'].max()
# Out:
# 25691.16

# %%
max_class = data.loc[data['Amount'].idxmax(), 'Class']
max_class
# Out:
# 0

# %%
sns.countplot(data = data, x= 'Class')
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
sns.histplot(data=data, x='Amount', bins=100)
plt.xlabel('Amount')
plt.ylabel('Count')
plt.title('Histogram of Amounts')
plt.show()

# %%
plt.figure(figsize=(20, 10))  # Width=12, Height=8
sns.heatmap(data.corr(), annot = True, cmap='coolwarm', fmt='.1f')
plt.title('Heatmap of correlation between data')
# Out:
# Text(0.5, 1.0, 'Heatmap of correlation between data')

# %% [markdown]
# 1. There are 284807 Rows and 31 columns in the dataset.
# 2. Column Names and their Datatypes are:
#    1. Time (float64)
#    2. V1 (float6)
#    3. V2 (float64)
#    4. V3 (float64)
#    5. V4 (float64)
#    6. V5 (float64)
#    7. V6 (float64)
#    8. V7 (float64)
#    9. V8 (float64)
#    10. V9 (float64)
#    11. V10 (float64)
#    12. V11 (float64)
#    13. V12 (float64)
#    14. V13 (float64)
#    15. V14 (float64)
#    16. V15 (float64)
#    17. V16 (float64)
#    18. V17 (float64)
#    19. V18 (float64)
#    20. V19 (float64)
#    21. V20 (float64)
#    22. V21 (float64)
#    23. V22 (float64)
#    24. V23 (float64)
#    25. V24 (float64)
#    26. V25 (float64)
#    27. V26 (float64)
#    28. V27 (float64)
#    29. V28 (float64)
#    30. Amount (float64)
#    31. Class (int64)a3s   284807 non-null  int64  4807 no
#  30
# 4. NO, There is not4any missing or null values in the dataset.
# 5. 492 Datasets are fra5dulent and 284315 datasets are legitimat6. Minimum, Maximum, Mean and Median Value:
#    1. Time: Minimum (0.0), Maximum (172792.0), Mean (94813.85), Median (84692.0)
#    2. Amount: Minimum (0.0), Maximum (25691.1), Mean (88.34), Median (22.00)
# 7. The maximum Amount is 25691.16 and it is not a Frudulent Transaction.:
#    ### Time ass   284807 non-null  int64
